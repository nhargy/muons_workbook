# %% [markdown]
# # Run {Class} Demo

# %%
from config.settings import ProjectRoot, LocalDataPath, OutPath, PlotsPath
from config.plot_config import set_plot_style; set_plot_style()

from models.run import Run

import os
import numpy as np
import matplotlib.pyplot as plt

# %%
run_TLV = np.load(f"{OutPath}/run_TLV.npy", allow_pickle=True)
run_SN = np.load(f"{OutPath}/run_SN.npy", allow_pickle=True)
run_WE = np.load(f"{OutPath}/run_WE.npy", allow_pickle=True)

# %%
timestamps = [x[0] for x in run_WE]

# %%
plt.hist(timestamps)
# Out:
# (array([370., 365., 381., 345., 351., 378., 362., 328., 105.,  91.]),
#  array([     0.  ,  10593.57,  21187.14,  31780.71,  42374.28,  52967.85,
#          63561.42,  74154.99,  84748.56,  95342.13, 105935.7 ]),
#  <BarContainer object of 10 artists>)
